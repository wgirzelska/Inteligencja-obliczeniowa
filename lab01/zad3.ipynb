# %% [markdown]
# Importy i odczyt z pliku

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

miasta = pd.read_csv('miasta.csv')

# %% [markdown]
# a) Wyświetlenie tabeli i czystych wartości tabeli

# %%
print(miasta)
print(miasta.values)
# Out:
#     Rok  Gdansk  Poznan  Szczecin
# 0  1900     170     110       210
# 1  1925     210     220       254
# 2  1939     250     274       287
# 3  1946     117     267        72
# 4  1950     194     320       178
# 5  1960     286     408       269
# 6  1970     365     471       338
# 7  1980     456     552       388
# 8  1990     465     590       413
# 9  2000     462     574       416
# [[1900  170  110  210]
#  [1925  210  220  254]
#  [1939  250  274  287]
#  [1946  117  267   72]
#  [1950  194  320  178]
#  [1960  286  408  269]
#  [1970  365  471  338]
#  [1980  456  552  388]
#  [1990  465  590  413]
#  [2000  462  574  416]]

# %% [markdown]
# b) Dodanie nowego wiersza za pomocą biblioteki pandas

# %%
nowy_wiersz = {"Rok": [2010], "Gdansk": [460], "Poznan": [555], "Szczecin": [405]}

df = pd.DataFrame(nowy_wiersz)

df.to_csv('miasta.csv', mode='a', index=False, header=False)
miasta2 = pd.read_csv('miasta.csv')

print(miasta2)
# Out:
#      Rok  Gdansk  Poznan  Szczecin
# 0   1900     170     110       210
# 1   1925     210     220       254
# 2   1939     250     274       287
# 3   1946     117     267        72
# 4   1950     194     320       178
# 5   1960     286     408       269
# 6   1970     365     471       338
# 7   1980     456     552       388
# 8   1990     465     590       413
# 9   2000     462     574       416
# 10  2010     460     555       405

# %% [markdown]
# c) Wykres ludności dla Gdańska<br>
# wczytujemy osobno kolumny Rok i Gdańsk i tworzymy z nich wykres

# %%
onlyGdansk = pd.read_csv("miasta.csv", usecols = ['Gdansk'])
rok = pd.read_csv("miasta.csv", usecols = ['Rok'])

ypoints = np.array(onlyGdansk)
xpoints = np.array(rok)

plt.scatter(xpoints, ypoints, color='red')
plt.plot(xpoints, ypoints, color='red')
plt.xlabel('Rok')
plt.ylabel('Ludność')
plt.title('Ludność Gdańska')
plt.show()

# %% [markdown]
# d) Wykres ludności dla wszystkich miast i legenda

# %%
onlyPoznan = pd.read_csv("miasta.csv", usecols = ['Poznan'])
onlySzczecin = pd.read_csv("miasta.csv", usecols = ['Szczecin'])

plt.plot(xpoints, onlyGdansk, label='Gdansk')
plt.plot(xpoints, onlyPoznan, label='Poznan')
plt.plot(xpoints, onlySzczecin, label='Szczecin')

plt.xlabel('Rok')
plt.ylabel('Ludność wszystkich miast')
plt.ylabel('Ludność')
plt.legend()
plt.show()

# %% [markdown]
# e) Standaryzacja (według wzoru)

# %%
miasta_std = (miasta - miasta.mean()) / miasta.std()

print("Średnia po skalowaniu:", miasta_std.mean())
print("Odchylenie standardowe po skalowaniu:", miasta_std.std())
# Out:
# Średnia po skalowaniu: Rok         2.220446e-17
# Gdansk      0.000000e+00
# Poznan     -1.554312e-16
# Szczecin    0.000000e+00
# dtype: float64
# Odchylenie standardowe po skalowaniu: Rok         1.0
# Gdansk      1.0
# Poznan      1.0
# Szczecin    1.0
# dtype: float64

# %% [markdown]
# f) Normalizacja (według wzoru)

# %%
miasta_norm = (miasta - miasta.min()) / (miasta.max() - miasta.min())

print("Wartość minimalna po skalowaniu:", miasta_norm.min())
print("Wartość maksymalna po skalowaniu:", miasta_norm.max())
# Out:
# Wartość minimalna po skalowaniu: Rok         0.0
# Gdansk      0.0
# Poznan      0.0
# Szczecin    0.0
# dtype: float64
# Wartość maksymalna po skalowaniu: Rok         1.0
# Gdansk      1.0
# Poznan      1.0
# Szczecin    1.0
# dtype: float64
